# %%
import pandas as pd

# %% [markdown]
# ## Task 1

# %%
bike_sharing = pd.read_csv('bike_sharing.csv')
print(bike_sharing.shape)
print(bike_sharing.columns.tolist())
bike_sharing.head()
# Out:
# (731, 16)
# ['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday', 'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'casual', 'registered', 'cnt']
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# ...

# %% [markdown]
# It looks like each row is a day that shows weather and the number of people who register for the bike sharing service

# %%
grad = pd.read_csv('grad.csv')
print(grad.shape)
print(grad.columns.tolist())
grad.head()
# Out:
# (400, 4)
# ['admit', 'gre', 'gpa', 'rank']
#    admit  gre   gpa  rank
# 0      0  380  3.61     3
# 1      1  660  3.67     3
# 2      1  800  4.00     1
# 3      1  640  3.19     4
# 4      0  520  2.93     4

# %% [markdown]
# Grad school admission and other labels

# %%
insurance = pd.read_csv('insurance.csv')
print(insurance.shape)
print(insurance.columns.tolist())
insurance.head()
# Out:
# (1338, 7)
# ['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges']
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# People's charges, and other life information

# %% [markdown]
# ## Task 2

# %%
insurance_target = insurance['charges']
insurance_target.head(10)
# Out:
# 0    16884.92400
# 1     1725.55230
# 2     4449.46200
# 3    21984.47061
# 4     3866.85520
# 5     3756.62160
# 6     8240.58960
# 7     7281.50560
# 8     6406.41070
# 9    28923.13692
# Name: charges, dtype: float64

# %% [markdown]
# The target column contains the amount that each person is paying for insurance.

# %%
grad_target = grad['admit']
grad_target.head(10)
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# 5    1
# 6    1
# 7    0
# 8    1
# 9    0
# Name: admit, dtype: int64

# %% [markdown]
# Whether each person got admitted to the graduate program

# %%
bike_sharing_target = bike_sharing['cnt']
bike_sharing_target.head(10)
# Out:
# 0     985
# 1     801
# 2    1349
# 3    1562
# 4    1600
# 5    1606
# 6    1510
# 7     959
# 8     822
# 9    1321
# Name: cnt, dtype: int64

# %% [markdown]
# The number of total bike rentals each day

# %% [markdown]
# ## Task 3

# %%
insurance_target.unique()
# Out:
# array([16884.924 ,  1725.5523,  4449.462 , ...,  1629.8335,  2007.945 ,
#        29141.3603], shape=(1337,))

# %% [markdown]
# Insurance- regression, as it looks like the target is a continuous numeric column

# %%
grad_target.unique()
# Out:
# array([0, 1])

# %% [markdown]
# Grad- binary classification as we only have 2 outcomes- yes or no

# %%
bike_sharing_target.unique()
# Out:
# array([ 985,  801, 1349, 1562, 1600, 1606, 1510,  959,  822, 1321, 1263,
#        1162, 1406, 1421, 1248, 1204, 1000,  683, 1650, 1927, 1543,  981,
#         986, 1416, 1985,  506,  431, 1167, 1098, 1096, 1501, 1360, 1526,
#        1550, 1708, 1005, 1623, 1712, 1530, 1605, 1538, 1746, 1472, 1589,
#        1913, 1815, 2115, 2475, 2927, 1635, 1812, 1107, 1450, 1917, 1807,
#        1461, 1969, 2402, 1446, 1851, 2134, 1685, 1944, 2077,  605, 1872,
#        2133, 1891,  623, 1977, 2132, 2417, 2046, 2056, 2192, 2744, 3239,
#        3117, 2471, 2703, 2121, 1865, 2210, 2496, 1693, 2028, 2425, 1536,
#        2227, 2252, 3249, 3115, 1795, 2808, 3141, 1471, 2455, 2895, 3348,
#        2034, 2162, 3267, 3126,  795, 3744, 3429, 3204, 3944, 4189, 1683,
#        4036, 4191, 4073, 4400, 3872, 4058, 4595, 5312, 3351, 4401, 4451,
#        2633, 4433, 4608, 4714, 4333, 4362, 4803, 4182, 4864, 4105, 3409,
#        4553, 3958, 4123, 3855, 4575, 4917, 5805, 4660, 4274, 4492, 4978,
# ...

# %% [markdown]
# Bike sharing- also regression because the target column is a continuous numeric variable
